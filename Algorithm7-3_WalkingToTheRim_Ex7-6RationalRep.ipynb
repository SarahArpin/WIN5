# %%
load("McMurdyCode.sage")

# %% [markdown]
# This is the code for Example 7.6. This example of this algorithm comes from Step 4 of the Finding a path to $E_{\text{init}}$ algorithm (Algorithm 8.1), which is a call to the Walking to the rim of the oriented $\ell$-isogeny graph algorithm (Algorithm 7.3)
#
#
# Initialize our field and input:

# %%
p =179
F.<TT>=GF(p)[]
K.<a>=GF(p^2,name='a',modulus=TT^2+1)
K4 = K.extension(2)
z4 = K4.gen()
R.<x>=PolynomialRing(K4)
E120 = EllipticCurve(K4, [K4(7*a+86),K4(45*a+174)])
W120 = x^3 + K4(7*a+86)*x + K4(45*a+174)
t120 = 20
n120 = (2^5)*(3^2)
THETA = [((122*a + 167)*x^288 + (17*a + 68)*x^287 + (113*a + 171)*x^286 + (148*a + 4)*x^285 + (153*a + 165)*x^284 + (159*a + 106)*x^283 + (109*a + 100)*x^282 + (91*a + 100)*x^281 + (12*a + 137)*x^280 + (132*a + 125)*x^279 + (36*a + 50)*x^278 + (150*a + 131)*x^277 + (89*a + 161)*x^276 + (159*a + 24)*x^275 + (96*a + 103)*x^274 + (42*a + 4)*x^273 + (47*a + 63)*x^272 + (48*a + 77)*x^271 + (73*a + 92)*x^270 + (95*a + 21)*x^269 + (53*a + 75)*x^268 + (73*a + 29)*x^267 + (30*a + 92)*x^266 + (112*a + 104)*x^265 + (171*a + 81)*x^264 + (105*a + 176)*x^263 + (147*a + 165)*x^262 + (169*a + 46)*x^261 + (87*a + 167)*x^260 + (21*a + 143)*x^259 + (97*a + 143)*x^258 + (176*a + 103)*x^257 + (116*a + 170)*x^256 + (55*a + 157)*x^255 + (40*a + 132)*x^254 + (123*a + 62)*x^253 + (30*a + 72)*x^252 + (128*a + 49)*x^251 + (86*a + 71)*x^250 + (130*a + 111)*x^249 + (111*a + 58)*x^248 + (50*a + 56)*x^247 + (168*a + 100)*x^246 + (40*a + 90)*x^245 + (113*a + 143)*x^244 + (62*a + 90)*x^243 + (56*a + 169)*x^242 + (100*a + 18)*x^241 + (56*a + 22)*x^240 + (79*a + 135)*x^239 + (97*a + 66)*x^238 + (147*a + 13)*x^237 + (35*a + 15)*x^236 + (47*a + 173)*x^235 + (159*a + 121)*x^234 + (34*a + 152)*x^233 + (149*a + 112)*x^232 + (133*a + 166)*x^231 + (55*a + 129)*x^230 + (144*a + 23)*x^229 + (142*a + 177)*x^228 + (170*a + 154)*x^227 + (29*a + 32)*x^226 + (6*a + 103)*x^225 + (160*a + 107)*x^224 + (35*a + 72)*x^223 + (138*a + 77)*x^222 + (34*a + 85)*x^221 + (2*a + 33)*x^220 + (62*a + 147)*x^219 + (161*a + 160)*x^218 + (75*a + 88)*x^217 + (28*a + 100)*x^216 + (164*a + 118)*x^215 + (48*a + 22)*x^214 + (110*a + 146)*x^213 + (122*a + 97)*x^212 + (31*a + 155)*x^211 + (121*a + 105)*x^210 + (69*a + 53)*x^209 + (59*a + 1)*x^208 + (168*a + 88)*x^207 + (50*a + 15)*x^206 + (74*a + 101)*x^205 + (97*a + 127)*x^204 + (5*a + 139)*x^203 + (178*a + 23)*x^202 
v2 = ZZ.valuation(2)

# %% [markdown]
# **Steps 1 - 2:** Set up an empty list and find $k$:

# %%
H = []
k = floor(v2(t120^2 - 4*n120)/2)
k
# Out:
# 2

# %% [markdown]
# **Step 3:** Check the condition in the **If** statement:

# %%
(ZZ((t120^2 -4*n120)/(2^(2*k)))).mod(4)
# Out:
# 1

# %% [markdown]
# The **If** condition is not satisfied, so we continue without changing $k$.
#
# The **For** loop Steps 5 - 12 will run for $j = 1,2$.
#
# **Step 5:** Begin with $j = 1$.

# %% [markdown]
# **Step 6:** Compute $E_{120}[2]$:

# %%
E120_2Tor = E120.division_polynomial(2).roots(multiplicities = False)

# %% [markdown]
# **Step 7:** We want a 2-suitable translate, so we call an algorithm to find the $T$ where $THETA + T$ is 2-suitable.

# %%
print(t120)
print(n120)
# Out:
# 20
# 288

# %% [markdown]
# The algorithm output is $T = -10$, so we proceed with THETA - 10:

# %%
EndoNeg1_120 = [x,R(-1)]
EndoNeg2_120 = EndoDouble(EndoNeg1_120,W120)
EndoNeg4_120 = EndoDouble(EndoNeg2_120,W120)
EndoNeg8_120 = EndoDouble(EndoNeg4_120,W120)
EndoNeg10_120 = EndoAdd(EndoNeg8_120, EndoNeg2_120, W120)

THETA_suitable = EndoAdd(THETA,EndoNeg10_120, W120)
THETA = THETA_suitable
#Update the trace and norm:
t120 = 0
n120 = THETA[0].denominator().degree()+1
n120
# Out:
# 188

# %%
K(165*z4^3 + 22*z4^2 + 35*z4 + 136)
# Out:
# 36*a + 106

# %%
THETA_suitable[1].denominator()
# Out:
# x^281 + (136*z4^3 + 42*z4^2 + 18*z4 + 146)*x^280 + (177*z4^3 + 131*z4^2 + 5*z4 + 112)*x^279 + (107*z4^3 + 62*z4^2 + z4 + 125)*x^278 + (z4^3 + 24*z4^2 + 87*z4 + 111)*x^277 + (138*z4^3 + 90*z4^2 + 13*z4 + 38)*x^276 + (28*z4^3 + 135*z4^2 + 109*z4 + 107)*x^275 + (52*z4^3 + 174*z4^2 + 49*z4 + 60)*x^274 + (91*z4^3 + 36*z4^2 + 41*z4 + 89)*x^273 + (175*z4^3 + 83*z4^2 + 10*z4 + 141)*x^272 + (135*z4^3 + 18*z4^2 + 110*z4 + 90)*x^271 + (60*z4^3 + 8*z4^2 + 29*z4 + 25)*x^270 + (159*z4^3 + 57*z4^2 + 50*z4 + 26)*x^269 + (93*z4^3 + 84*z4^2 + 36*z4 + 131)*x^268 + (20*z4^3 + 122*z4^2 + 129*z4 + 7)*x^267 + (126*z4^3 + 160*z4^2 + 43*z4 + 96)*x^266 + (12*z4^3 + 109*z4^2 + 149*z4 + 172)*x^265 + (38*z4^3 + 17*z4^2 + 84*z4 + 41)*x^264 + (167*z4^3 + 70*z4^2 + 30*z4 + 120)*x^263 + (155*z4^3 + 140*z4^2 + 60*z4 + 23)*x^262 + (81*z4^3 + 154*z4^2 + 66*z4 + 142)*x^261 + (105*z4^3 + 14*z4^2 + 6*z4 + 112)*x^260 + (173*z4^3 + 35*z4^2 + 15*z4 + 145)*x^259 + (154*z4^3 + 116*z4^2 + 152*z4 + 136)*x^258 + (135*z4^3 + 18*z4
# ...

# %% [markdown]
# **Step 8:** Compute $E_{120}[2]\cap \ker(THETA)$:

# %%
for x_val in E120_2Tor:
    if THETA[0].denominator()(x = x_val) == 0:
        print(K(x_val))
# Out:
# 121*a + 4

# %% [markdown]
# **Step 9:** Use Velu's formulas to define an isogeny with this kernel:

# %%
nu1 = EllipticCurveIsogeny(E120,E120.lift_x(122*z4^3 + 64*z4^2 + 53*z4 + 75))
E171 = EllipticCurve(K4, [K4(120*a+119), K4(66*a+112)])
W171 = x^3 + K4(120*a+119)*x + K4(66*a+112)
nu1.set_post_isomorphism(nu1.codomain().isomorphism_to(E171))
nu1.dual()
nu1dual = nu1.dual()
nu1dual.set_post_isomorphism(nu1dual.codomain().isomorphism_to(E120))
#print(nu1.domain() == E120)
#print(nu1dual.codomain() == E120)
#print(nu1.codomain() == E171)
#print(nu1dual.domain() == E171)

# %%
nu1_m = [(45*x^2 + (59*z4^3 - 16*z4^2 - 58*z4 + 26)*x + (-17*z4^3 - 50*z4^2 - 47*z4 - 11))/(x + (57*z4^3 - 64*z4^2 - 53*z4 - 75)), (67*x^2 + (-59*z4^3 + 16*z4^2 + 58*z4 - 26)*x + (-41*z4^3 - 89*z4^2 + 13*z4 - 16))/(x^2 + (-65*z4^3 + 51*z4^2 + 73*z4 + 29)*x + (81*z4^3 - 25*z4^2 + 66*z4 + 84))]
nu1dual_m = [(x^2 + (61*z4^3 + 32*z4^2 - 63*z4 - 52)*x + (29*z4^3 - 20*z4^2 + 17*z4 - 76))/(x + (61*z4^3 + 32*z4^2 - 63*z4 - 52)), ((50*z4^3 - 53*z4^2 + 54*z4 - 18)*x^2 + (3*z4^3 + 72*z4^2 + 82*z4 + 53)*x - 79)/((50*z4^3 - 53*z4^2 + 54*z4 - 18)*x^2 + (3*z4^3 + 72*z4^2 + 82*z4 + 53)*x - 78)]

# %% [markdown]
# **Step 10:** Replace our previous traced endomorphism with $(E_{171},\nu\circ THETA \circ \hat{\nu}, t_{120}\cdot 2,n_{120}\cdot 2^2)$.
#
# Let $THETA171 := \nu\circ THETA \circ \hat{\nu}, t_{171} := 2t_{120}, n_{171} := 4n_{120}$.

# %%
THETA171 = IsoCompose(nu1dual_m,IsoCompose(THETA,nu1_m))
t171 = 2*t120
n171 = 4*n120
print(t171)
print(n171)
# Out:
# 0
# 752

# %% [markdown]
# **Step 11:** Divide by $[2]$ twice and obtain a new traced endormophism:

# %%
temp = DivideBy2(THETA171, W171)

# %%
THETA171_dividedby4 = DivideBy2(temp, W171)

# %%
t171 = t171/(2^2)
print(t171)
n171 = n171/(2^4)
print(n171)
# Out:
# 0
# 47

# %% [markdown]
# **Step 12:** Append our new traced endomorphism to $H$:

# %%
H.append([nu1,[E171,THETA171_dividedby4,t171,n171]])

# %% [markdown]
# Now, back to **Step 5** with $j = 2 = k$:
#
# **Step 6:** Compute $E_{171}[2]$:

# %%
E171_2Tor = E171.division_polynomial(2).roots(multiplicities = False)

# %% [markdown]
# **Step 7:** Find an $\ell$-suitable translate of our traced endomorphism.

# %%
print(t171)
print(n171)
# Out:
# 0
# 47

# %% [markdown]
# The endomorphism (THETA171 + 1) is 2-suitable. Compute this endomorphism and rename it THETA171:

# %%
Endo1_171 = [x,R(1)]
THETA_171suit = EndoAdd(THETA171_dividedby4,Endo1_171,W171)
THETA171 = THETA_171suit
print(THETA171[0].denominator().degree() + 1)
# Out:
# 48

# %% [markdown]
# This new $2$-suitable endomorphism has trace 2 and norm 48.

# %%
t171 = 2
n171 = 48

# %% [markdown]
# **Step 8:** Figure out the intersection of $\ker(THETA171 - 4)\cap E_{171}[2]$:

# %%
for pt in E171_2Tor:
    if THETA_171suit[0].denominator()(x = pt) == 0:
        print(K(pt))
# Out:
# 121*a + 131

# %% [markdown]
# **Step 9:** Define an isogeny using this kernel.

# %%
nu2 = EllipticCurveIsogeny(E171,E171.lift_x(122*z4^3 + 64*z4^2 + 53*z4 + 23))
E5aplus109=EllipticCurve(K4,[120*a+69,5*a+43])
W5aplus109=x^3 + K4(120*a+69)*x + K4(5*a+43)
nu2.set_post_isomorphism(nu2.codomain().isomorphism_to(E5aplus109))
nu2dual = nu2.dual()

# %%
nu2_m = [(45*x^2 + (59*z4^3 - 16*z4^2 - 58*z4 + 39)*x + (35*z4^3 - 55*z4^2 + 2*z4 + 10))/(x + (57*z4^3 - 64*z4^2 - 53*z4 - 23)),
 (67*x^2 + (-59*z4^3 + 16*z4^2 + 58*z4 - 39)*x + (-40*z4^3 - 65*z4^2 - 79*z4 + 5))/(x^2 + (-65*z4^3 + 51*z4^2 + 73*z4 - 46)*x + (-77*z4^3 - 58*z4^2 - 76*z4))]
nu2dual_m = [(x^2 + (61*z4^3 + 32*z4^2 - 63*z4 - 78)*x - 10)/(x + (61*z4^3 + 32*z4^2 - 63*z4 - 78)),
 (-18*x^2 + (-48*z4^3 - 78*z4^2 - 59*z4 - 56)*x + (78*z4^3 + 82*z4^2 - 16*z4 - 1))/(18*x^2 + (48*z4^3 + 78*z4^2 + 59*z4 + 56)*x + (-78*z4^3 - 82*z4^2 + 16*z4))]

# %% [markdown]
# **Step 10:** Apply the Waterhouse twist and obtain the new traced endomorphism.

# %%
THETA5aplus109 = IsoCompose(nu2dual_m,IsoCompose(THETA_171suit,nu2_m))
t5aplus109 = t171*2
print(t5aplus109)
n5aplus109 = n171*4
print(n5aplus109)
# Out:
# 4
# 192

# %% [markdown]
# **Step 11:** Divide by $[2]$ twice:

# %%
temp = DivideBy2(THETA5aplus109, W5aplus109)
THETA5aplus109_dividedby4 = DivideBy2(temp,W5aplus109)

# %% [markdown]
# **Step 12:** Append the updated traced endomorphism to the list $H$ and we are done:

# %%
H.append([nu2,[E5aplus109,THETA5aplus109_dividedby4,t5aplus109/4,n5aplus109/16]])

# %%
len(H)
# Out:
# 2
